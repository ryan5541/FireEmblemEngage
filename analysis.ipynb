# %%
import pandas as pd
import matplotlib as plt

# %%
character_classes = pd.read_csv('character_classes.csv')

# %%
character_classes
# Out:
#      Character           Class  HP  Str  Mag  Dex  Spd  Def  Res  Lck  Bld
# 0        Alear    Dragon Child  70   45   20   55   65   50   35   30   10
# 1        Alear   Divine Dragon  70   45   20   55   65   55   40   35   10
# 2        Alear   Sword Fighter  70   45   20   60   70   40   40   35    5
# 3        Alear     Swordmaster  70   45   20   60   70   40   40   40    5
# 4        Alear            Hero  75   50   20   55   65   40   35   40    5
# ...        ...             ...  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 1238      Jean     Lance Flier  55   30   25   45   50   25   30   35    5
# 1239      Jean       Axe Flier  55   30   25   45   50   25   30   35    5
# 1240      Jean  Griffin Knight  50   30   35   50   60   25   35   40    5
# 1241      Jean   Wyvern Knight  70   40   20   45   45   45   25   30   10
# 1242      Jean           Thief  55   30   20   55   55   40   25   40    5
#
# [1243 rows x 11 columns]

# %%
character_classes[character_classes['Character'] == 'Alfred'].sort_values('Str', ascending = False)
# Out:
#     Character           Class  HP  Str  Mag  Dex  Spd  Def  Res  Lck  Bld
# 147    Alfred       Berserker  95   70    5   40   50   45   20   40   20
# 172    Alfred   Wyvern Knight  85   60    5   45   45   60   25   45   15
# 155    Alfred         General  90   60    5   45   40   70   20   40   20
# 146    Alfred     Axe Fighter  90   60    5   40   50   45   20   40   15
# 148    Alfred         Warrior  90   60    5   45   55   50   25   40   15
# 138    Alfred  Noble (Alfred)  80   55    5   40   45   60   25   55   10
# 150    Alfred          Sniper  80   55    5   65   50   50   20   50   10
# 160    Alfred         Paladin  80   55    5   45   55   55   35   50   10
# 139    Alfred          Avenir  80   55    5   40   50   65   25   60   15
# 154    Alfred       Axe Armor  85   55    5   45   40   70   20   40   15
# 153    Alfred     Lance Armor  85   55    5   45   40   70   20   40   15
# 152    Alfred     Sword Armor  85   55    5   45   40   70   20   40   15
# ...

# %%
characters = pd.read_csv('characters_cleaned.csv')
characters
# Out:
#          Name  HP  Str  Mag  Dex  Spd  Def  Res  Lck  Bld
# 0       Alear  60   35   20   45   50   40   25   25    5
# 1      Vander  60   25   10   25   35   35   20   10    5
# 2      Clanne  40   35   10   40   50   30   25   20    5
# 3      Framme  55   30   25   35   55   25   30   25    0
# 4      Alfred  65   40    5   35   40   40   20   40   10
# 5        Etie  45   40    0   25   35   25   30   25    5
# 6   Boucheron  85   20    0   50   45   35   20   15   20
# 7      Celine  50   35   25   30   45   30   40   50    5
# 8       Chloe  75   25   35   40   55   30   25   25    5
# 9       Louis  75   40    0   25   25   50   20   25   15
# 10     Yunaka  50   35   25   40   45   15   45   25    5
# 11    Alcryst  65   30   10   40   45   30   20   15   10
# 12   Citrinne  45   10   40   25   30   20   40   25    5
# 13      Lapis  55   25   20   35   55   35   30   25    5
# 14    Diamant  75   30   15   20   40   40   25   20   15
# ...
